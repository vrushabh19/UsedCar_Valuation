# %%
# Importing the required libraries 

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import date

# Preprocessing libraries
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

# Model selection library
from sklearn.model_selection import train_test_split

# Model Building libraries
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from xgboost import XGBRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor

# Scaling library
from sklearn.preprocessing import StandardScaler

# Cross validation
from sklearn.model_selection import cross_val_score

# Model Evaluation libraries
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error, mean_absolute_percentage_error

# Importing folium to see map
import folium

# %%
# Setting option to see all columns at once

pd.set_option('display.max_columns', None)

# Setting grid n background for visualization

sns.set_style('whitegrid')

# %% [markdown]
# ## Approach:
#
# #### 1) EDA
# #### 2) Data Pre-processing
# #### 4) Model Building
# #### 5) Model Evaluation

# %%
# Reading CSV file 

car = pd.read_csv('vehicles_data.csv')

# %%
# Check first 5 rows from dataset

car.head()
# Out:
#            id                                                url  region  \
# 0  7316814884  https://auburn.craigslist.org/ctd/d/auburn-uni...  auburn
# 1  7316814758  https://auburn.craigslist.org/ctd/d/auburn-uni...  auburn
# 2  7316814989  https://auburn.craigslist.org/ctd/d/auburn-uni...  auburn
# 3  7316743432  https://auburn.craigslist.org/ctd/d/auburn-uni...  auburn
# 4  7316356412  https://auburn.craigslist.org/cto/d/auburn-uni...  auburn
#
#                       region_url  price    year manufacturer  \
# 0  https://auburn.craigslist.org  33590  2014.0          gmc
# 1  https://auburn.craigslist.org  22590  2010.0    chevrolet
# 2  https://auburn.craigslist.org  39590  2020.0    chevrolet
# 3  https://auburn.craigslist.org  30990  2017.0       toyota
# 4  https://auburn.craigslist.org  15000  2013.0         ford
#
#                       model  condition    cylinders fuel  odometer  \
# 0  sierra 1500 crew cab slt       good  8 cylinders  gas   57923.0
# 1            silverado 1500       good  8 cylinders  gas   71229.0
# 2       silverado 1500 crew       good  8 cylinders  gas   19160.0
# 3      tundra double cab sr       good  8 cylinders  gas   41124.0
# 4                 f-150 xlt  excellent  6 cylinders  gas  128000.0
#
#   title_status transmission                VIN drive       size    type  \
# 0        clean        other  3GTP1VEC4EG551563   NaN        NaN  pickup
# 1        clean        other  1GCSCSE06AZ123805   NaN        NaN  pickup
# 2        clean        other  3GCPWCED5LG130317   NaN        NaN  pickup
# 3        clean        other  5TFRM5F17HX120972   NaN        NaN  pickup
# 4        clean    automatic                NaN   rwd  full-size   truck
#
#   paint_color                                          image_url  \
# 0       white  https://images.craigslist.org/00R0R_lwWjXSEWNa...
# 1        blue  https://images.craigslist.org/00R0R_lwWjXSEWNa...
# 2         red  https://images.craigslist.org/01212_jjirIWa0y0...
# 3         red  https://images.craigslist.org/00x0x_1y9kIOzGCF...
# 4       black  https://images.craigslist.org/00404_l4loxHvdQe...
#
#                                          description  county state     lat  \
# 0  Carvana is the safer way to buy a car During t...     NaN    al  32.590
# 1  Carvana is the safer way to buy a car During t...     NaN    al  32.590
# 2  Carvana is the safer way to buy a car During t...     NaN    al  32.590
# 3  Carvana is the safer way to buy a car During t...     NaN    al  32.590
# 4  2013 F-150 XLT V6 4 Door. Good condition. Leve...     NaN    al  32.592
#
#       long              posting_date
# 0 -85.4800  2021-05-04T12:31:18-0500
# 1 -85.4800  2021-05-04T12:31:08-0500
# 2 -85.4800  2021-05-04T12:31:25-0500
# 3 -85.4800  2021-05-04T10:41:31-0500
# 4 -85.5189  2021-05-03T14:02:03-0500

# %%
# Checking shape of dataset

print(car.shape)

print('\nThere are {} records and {} features.'.format(car.shape[0], car.shape[1]))
# Out:
# (25000, 26)
#
# There are 25000 records and 26 features.

# %%
# Summary of dataset 

car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 26 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            25000 non-null  int64
#  1   url           25000 non-null  object
#  2   region        25000 non-null  object
#  3   region_url    25000 non-null  object
#  4   price         25000 non-null  int64
#  5   year          25000 non-null  float64
#  6   manufacturer  24197 non-null  object
#  7   model         24745 non-null  object
#  8   condition     14618 non-null  object
#  9   cylinders     14810 non-null  object
#  10  fuel          24863 non-null  object
#  11  odometer      25000 non-null  float64
#  12  title_status  24710 non-null  object
#  13  transmission  24943 non-null  object
#  14  VIN           16162 non-null  object
#  15  drive         17705 non-null  object
#  16  size          6512 non-null   object
#  17  type          19620 non-null  object
#  18  paint_color   18400 non-null  object
#  19  image_url     25000 non-null  object
#  20  description   24999 non-null  object
#  21  county        0 non-null      float64
#  22  state         25000 non-null  object
#  23  lat           24913 non-null  float64
#  24  long          24913 non-null  float64
#  25  posting_date  25000 non-null  object
# dtypes: float64(5), int64(2), object(19)
# memory usage: 5.0+ MB

# %% [markdown]
# #### From the Summary we can observe that there are 7 Numerical features & 19 Categorical features.

# %%
# Getting Descriptive Statistics of Numerical Features.

car.describe().round(2)
# Out:
#                  id      price      year   odometer  county       lat  \
# count  2.500000e+04   25000.00  25000.00   25000.00     0.0  24913.00
# mean   7.311343e+09   19814.19   2013.07   85699.97     NaN     38.16
# std    4.507832e+06   15361.09      5.74   62389.38     NaN      9.39
# min    7.301591e+09       0.00   1990.00       0.00     NaN    -81.84
# 25%    7.307769e+09    7900.00   2010.00   32641.75     NaN     33.41
# 50%    7.312296e+09   17220.00   2015.00   75636.50     NaN     34.62
# 75%    7.315379e+09   29590.00   2017.00  125950.75     NaN     36.84
# max    7.316901e+09  100000.00   2020.00  300000.00     NaN     64.99
#
#            long
# count  24913.00
# mean    -110.33
# std       19.73
# min     -158.60
# 25%     -119.44
# 50%     -111.80
# 75%      -92.36
# max      173.89

# %% [markdown]
# #### We can see that the minimum value of 'Price' and 'Odometer' feature is zero.
# #### But in real world scenario we know the price and odometer cannot be zero of used cars. So we will get rid of these in Data Cleaning.

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Steps :
#
# 1. Dropping unwanted columns like id, url, region_url, VIN, image_url, description, posting_date.
# 2. Setting a threshold for 'price' and 'odometer' feature to get rid of low values.
# 3. Handling the missing values.
# 4. Check duplicate values.

# %%
# Creating a copy of original dataset

df = car.copy()

# %%
# Check first 5 rows from copy dataset

df.head()
# Out:
#            id                                                url  region  \
# 0  7316814884  https://auburn.craigslist.org/ctd/d/auburn-uni...  auburn
# 1  7316814758  https://auburn.craigslist.org/ctd/d/auburn-uni...  auburn
# 2  7316814989  https://auburn.craigslist.org/ctd/d/auburn-uni...  auburn
# 3  7316743432  https://auburn.craigslist.org/ctd/d/auburn-uni...  auburn
# 4  7316356412  https://auburn.craigslist.org/cto/d/auburn-uni...  auburn
#
#                       region_url  price    year manufacturer  \
# 0  https://auburn.craigslist.org  33590  2014.0          gmc
# 1  https://auburn.craigslist.org  22590  2010.0    chevrolet
# 2  https://auburn.craigslist.org  39590  2020.0    chevrolet
# 3  https://auburn.craigslist.org  30990  2017.0       toyota
# 4  https://auburn.craigslist.org  15000  2013.0         ford
#
#                       model  condition    cylinders fuel  odometer  \
# 0  sierra 1500 crew cab slt       good  8 cylinders  gas   57923.0
# 1            silverado 1500       good  8 cylinders  gas   71229.0
# 2       silverado 1500 crew       good  8 cylinders  gas   19160.0
# 3      tundra double cab sr       good  8 cylinders  gas   41124.0
# 4                 f-150 xlt  excellent  6 cylinders  gas  128000.0
#
#   title_status transmission                VIN drive       size    type  \
# 0        clean        other  3GTP1VEC4EG551563   NaN        NaN  pickup
# 1        clean        other  1GCSCSE06AZ123805   NaN        NaN  pickup
# 2        clean        other  3GCPWCED5LG130317   NaN        NaN  pickup
# 3        clean        other  5TFRM5F17HX120972   NaN        NaN  pickup
# 4        clean    automatic                NaN   rwd  full-size   truck
#
#   paint_color                                          image_url  \
# 0       white  https://images.craigslist.org/00R0R_lwWjXSEWNa...
# 1        blue  https://images.craigslist.org/00R0R_lwWjXSEWNa...
# 2         red  https://images.craigslist.org/01212_jjirIWa0y0...
# 3         red  https://images.craigslist.org/00x0x_1y9kIOzGCF...
# 4       black  https://images.craigslist.org/00404_l4loxHvdQe...
#
#                                          description  county state     lat  \
# 0  Carvana is the safer way to buy a car During t...     NaN    al  32.590
# 1  Carvana is the safer way to buy a car During t...     NaN    al  32.590
# 2  Carvana is the safer way to buy a car During t...     NaN    al  32.590
# 3  Carvana is the safer way to buy a car During t...     NaN    al  32.590
# 4  2013 F-150 XLT V6 4 Door. Good condition. Leve...     NaN    al  32.592
#
#       long              posting_date
# 0 -85.4800  2021-05-04T12:31:18-0500
# 1 -85.4800  2021-05-04T12:31:08-0500
# 2 -85.4800  2021-05-04T12:31:25-0500
# 3 -85.4800  2021-05-04T10:41:31-0500
# 4 -85.5189  2021-05-03T14:02:03-0500

# %%
# Drop unwanted columns.

df.drop(['id', 'url', 'region_url', 'VIN', 'image_url', 'description', 'posting_date'], axis = 1, inplace = True)

# %%
# Checking dataset after dropping unwanted columns.

df.head()
# Out:
#    region  price    year manufacturer                     model  condition  \
# 0  auburn  33590  2014.0          gmc  sierra 1500 crew cab slt       good
# 1  auburn  22590  2010.0    chevrolet            silverado 1500       good
# 2  auburn  39590  2020.0    chevrolet       silverado 1500 crew       good
# 3  auburn  30990  2017.0       toyota      tundra double cab sr       good
# 4  auburn  15000  2013.0         ford                 f-150 xlt  excellent
#
#      cylinders fuel  odometer title_status transmission drive       size  \
# 0  8 cylinders  gas   57923.0        clean        other   NaN        NaN
# 1  8 cylinders  gas   71229.0        clean        other   NaN        NaN
# 2  8 cylinders  gas   19160.0        clean        other   NaN        NaN
# 3  8 cylinders  gas   41124.0        clean        other   NaN        NaN
# 4  6 cylinders  gas  128000.0        clean    automatic   rwd  full-size
#
#      type paint_color  county state     lat     long
# 0  pickup       white     NaN    al  32.590 -85.4800
# 1  pickup        blue     NaN    al  32.590 -85.4800
# 2  pickup         red     NaN    al  32.590 -85.4800
# 3  pickup         red     NaN    al  32.590 -85.4800
# 4   truck       black     NaN    al  32.592 -85.5189

# %%
# Set threshold value for 'price' & 'odometer'.

# Price >= 1000
# Odometer >= 1000

df = df[(df['price'] >= 1000) & (df['odometer'] >= 1000)]

# %%
# Check shape of new dataset

print(df.shape)

print('\nThere new dataset has {} records and {} features.'.format(df.shape[0], df.shape[1]))
# Out:
# (22118, 19)
#
# There new dataset has 22118 records and 19 features.

# %%
# Getting Descriptive Statistics of Final Dataset.

df.describe().round(2)
# Out:
#           price      year   odometer  county       lat      long
# count  22118.00  22118.00   22118.00     0.0  22073.00  22073.00
# mean   22028.83   2012.97   87341.85     NaN     38.48   -110.74
# std    14482.33      5.77   62085.35     NaN      9.73     20.17
# min     1000.00   1990.00    1000.00     NaN    -81.84   -158.60
# 25%    10499.00   2010.00   33653.00     NaN     33.40   -119.70
# 50%    19500.00   2014.00   78013.50     NaN     34.62   -111.80
# 75%    30499.75   2017.00  127701.00     NaN     38.23    -92.35
# max    98995.00   2020.00  300000.00     NaN     64.99    -74.28

# %%
# Check for missing values.

# Get missing values in %
missing = df.isnull().sum()/len(df)*100

missing.nlargest(19).to_frame().style.background_gradient(cmap = 'Blues')
# Out:
# <style type="text/css">
# #T_68771_row0_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_68771_row1_col0 {
#   background-color: #2272b6;
#   color: #f1f1f1;
# }
# #T_68771_row2_col0 {
#   background-color: #94c4df;
#   color: #000000;
# }
# #T_68771_row3_col0 {
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_68771_row4_col0 {
#   background-color: #bdd7ec;
#   color: #000000;
# }
# #T_68771_row5_col0 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_68771_row6_col0 {
#   background-color: #d1e2f3;
#   color: #000000;
# }
# #T_68771_row7_col0 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_68771_row8_col0 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_68771_row9_col0 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_68771_row10_col0 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_68771_row11_col0, #T_68771_row12_col0, #T_68771_row13_col0, #T_68771_row14_col0, #T_68771_row15_col0, #T_68771_row16_col0, #T_68771_row17_col0, #T_68771_row18_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_68771_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_68771_level0_row0" class="row_heading level0 row0" >county</th>
#       <td id="T_68771_row0_col0" class="data row0 col0" >100.000000</td>
#     </tr>
#     <tr>
#       <th id="T_68771_level0_row1" class="row_heading level0 row1" >size</th>
#       <td id="T_68771_row1_col0" class="data row1 col0" >74.423546</td>
#     </tr>
#     <tr>
#       <th id="T_68771_level0_row2" class="row_heading level0 row2" >condition</th>
#       <td id="T_68771_row2_col0" class="data row2 col0" >40.071435</td>
#     </tr>
#     <tr>
#       <th id="T_68771_level0_row3" class="row_heading level0 row3" >cylinders</th>
#       <td id="T_68771_row3_col0" class="data row3 col0" >39.063206</td>
#     </tr>
#     <tr>
#       <th id="T_68771_level0_row4" class="row_heading level0 row4" >drive</th>
#       <td id="T_68771_row4_col0" class="data row4 col0" >27.809929</td>
#     </tr>
#     <tr>
#       <th id="T_68771_level0_row5" class="row_heading level0 row5" >paint_color</th>
#       <td id="T_68771_row5_col0" class="data row5 col0" >24.545619</td>
#     </tr>
#     <tr>
#       <th id="T_68771_level0_row6" class="row_heading level0 row6" >type</th>
#       <td id="T_68771_row6_col0" class="data row6 col0" >19.197034</td>
#     </tr>
#     <tr>
#       <th id="T_68771_level0_row7" class="row_heading level0 row7" >manufacturer</th>
#       <td id="T_68771_row7_col0" class="data row7 col0" >2.875486</td>
#     </tr>
#     <tr>
#       <th id="T_68771_level0_row8" class="row_heading level0 row8" >title_status</th>
#       <td id="T_68771_row8_col0" class="data row8 col0" >1.193598</td>
#     </tr>
#     <tr>
#       <th id="T_68771_level0_row9" class="row_heading level0 row9" >model</th>
#       <td id="T_68771_row9_col0" class="data row9 col0" >0.944932</td>
#     </tr>
#     <tr>
#       <th id="T_68771_level0_row10" class="row_heading level0 row10" >fuel</th>
#       <td id="T_68771_row10_col0" class="data row10 col0" >0.610363</td>
#     </tr>
#     <tr>
#       <th id="T_68771_level0_row11" class="row_heading level0 row11" >transmission</th>
#       <td id="T_68771_row11_col0" class="data row11 col0" >0.248666</td>
#     </tr>
#     <tr>
#       <th id="T_68771_level0_row12" class="row_heading level0 row12" >lat</th>
#       <td id="T_68771_row12_col0" class="data row12 col0" >0.203454</td>
#     </tr>
#     <tr>
#       <th id="T_68771_level0_row13" class="row_heading level0 row13" >long</th>
#       <td id="T_68771_row13_col0" class="data row13 col0" >0.203454</td>
#     </tr>
#     <tr>
#       <th id="T_68771_level0_row14" class="row_heading level0 row14" >price</th>
#       <td id="T_68771_row14_col0" class="data row14 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_68771_level0_row15" class="row_heading level0 row15" >odometer</th>
#       <td id="T_68771_row15_col0" class="data row15 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_68771_level0_row16" class="row_heading level0 row16" >state</th>
#       <td id="T_68771_row16_col0" class="data row16 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_68771_level0_row17" class="row_heading level0 row17" >year</th>
#       <td id="T_68771_row17_col0" class="data row17 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_68771_level0_row18" class="row_heading level0 row18" >region</th>
#       <td id="T_68771_row18_col0" class="data row18 col0" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### There's lot of features in the dataset which has missing values. The 'county' feature has 100% missing values & 'size' feature has 74% missing values which is the most among all.
#
# 1. We will drop the feature which has more that 50% of missing values.
# 2. For features less than 50% missing values we will replace it.

# %%
# Drop feature with more than 50% null values

df.drop(['county', 'size'], axis = 1, inplace = True)

# Reset index

df.reset_index(drop = True, inplace = True)

# %%
# Check unique values of all caregorical features.

# Get all actegorical features in a list. 
cat_fea = [i for i in df.columns if df[i].dtypes == 'O']

# Print all unqiue values. 
for feature in cat_fea:
    num_unique = df[feature].nunique()
    unique = df[feature].unique()
    mode = df[feature].mode()
    print()
    print('Number of unique values :', num_unique)
    print()
    print('Unique values of ', feature, ': ', unique)
    print()
    print('Mode :', mode[0], '\n')
    print('-'*100)
# Out:
# Number of unique values : 29
#
# Unique values of  region :  ['auburn' 'birmingham' 'dothan' 'florence / muscle shoals'
#  'gadsden-anniston' 'huntsville / decatur' 'mobile' 'montgomery'
#  'tuscaloosa' 'anchorage / mat-su' 'fairbanks' 'kenai peninsula'
#  'southeast alaska' 'flagstaff / sedona' 'mohave county' 'phoenix'
#  'prescott' 'show low' 'sierra vista' 'tucson' 'yuma' 'fayetteville'
#  'fort smith' 'jonesboro' 'little rock' 'texarkana' 'bakersfield' 'chico'
#  'fresno / madera']
#
# Mode : tucson
#
# ----------------------------------------------------------------------------------------------------
#
# Number of unique values : 38
#
# Unique values of  manufacturer :  ['gmc' 'chevrolet' 'toyota' 'ford' 'jeep' 'nissan' 'ram' 'mazda'
#  'cadillac' 'honda' 'dodge' 'lexus' 'jaguar' 'chrysler' 'volvo' 'audi'
#  'infiniti' 'lincoln' 'alfa-romeo' 'subaru' nan 'acura' 'hyundai' 'buick'
#  'mercedes-benz' 'bmw' 'mitsubishi' 'volkswagen' 'porsche' 'kia' 'rover'
#  'ferrari' 'mini' 'pontiac' 'fiat' 'tesla' 'saturn' 'mercury'
#  'harley-davidson']
#
# Mode : ford
#
# ----------------------------------------------------------------------------------------------------
#
# Number of unique values : 4645
#
# Unique values of  model :  ['sierra 1500 crew cab slt' 'silverado 1500' 'silverado 1500 crew' ...
#  'flex secrossover' 'transit wagon 350' 'workhorse stepvan']
#
# Mode : f-150
#
# ----------------------------------------------------------------------------------------------------
#
# Number of unique values : 6
#
# Unique values of  condition :  ['good' 'excellent' 'fair' 'like new' nan 'new' 'salvage']
#
# Mode : good
#
# ----------------------------------------------------------------------------------------------------
#
# Number of unique values : 8
#
# Unique values of  cylinders :  ['8 cylinders' '6 cylinders' nan '4 cylinders' '5 cylinders' '3 cylinders'
#  '10 cylinders' '12 cylinders' 'other']
#
# Mode : 6 cylinders
#
# ----------------------------------------------------------------------------------------------------
#
# Number of unique values : 5
#
# Unique values of  fuel :  ['gas' 'other' 'diesel' 'hybrid' nan 'electric']
#
# Mode : gas
#
# ----------------------------------------------------------------------------------------------------
#
# Number of unique values : 6
#
# Unique values of  title_status :  ['clean' 'rebuilt' 'lien' nan 'salvage' 'missing' 'parts only']
#
# Mode : clean
#
# ----------------------------------------------------------------------------------------------------
#
# Number of unique values : 3
#
# Unique values of  transmission :  ['other' 'automatic' 'manual' nan]
#
# Mode : automatic
#
# ----------------------------------------------------------------------------------------------------
#
# Number of unique values : 3
#
# Unique values of  drive :  [nan 'rwd' '4wd' 'fwd']
#
# Mode : 4wd
#
# ----------------------------------------------------------------------------------------------------
#
# Number of unique values : 13
#
# Unique values of  type :  ['pickup' 'truck' 'other' nan 'coupe' 'SUV' 'hatchback' 'mini-van' 'sedan'
#  'offroad' 'bus' 'convertible' 'wagon' 'van']
#
# Mode : sedan
#
# ----------------------------------------------------------------------------------------------------
#
# Number of unique values : 12
#
# Unique values of  paint_color :  ['white' 'blue' 'red' 'black' 'silver' 'grey' nan 'brown' 'yellow'
#  'orange' 'green' 'custom' 'purple']
#
# Mode : white
#
# ----------------------------------------------------------------------------------------------------
#
# Number of unique values : 5
#
# Unique values of  state :  ['al' 'ak' 'az' 'ar' 'ca']
#
# Mode : az
#
# ----------------------------------------------------------------------------------------------------

# %%
# Rplacing null values.

for i in df.columns:
    if df[i].isnull().sum() > 1:
        if df[i].dtype == 'O':
            mode = df[i].mode()
            df[i] = np.where(df[i].isnull(), mode, df[i])        # Rplacing categorical null values with mode.
        else:
            median = df[i].median()
            df[i] = np.where(df[i].isnull(), median, df[i])      # Rplacing numerical null values with median.

# %%
# Check again for null values

df.isnull().sum()
# Out:
# region          0
# price           0
# year            0
# manufacturer    0
# model           0
# condition       0
# cylinders       0
# fuel            0
# odometer        0
# title_status    0
# transmission    0
# drive           0
# type            0
# paint_color     0
# state           0
# lat             0
# long            0
# dtype: int64

# %% [markdown]
# #### Now that we have handled all the missing values we can proceed for further analysis.

# %%
# Check for any duplicate values.

df[df.duplicated()]
# Out:
#                 region  price    year manufacturer               model  \
# 352         birmingham   3399  2006.0        buick            lacrosse
# 355         birmingham   3900  2009.0      hyundai             elantra
# 358         birmingham   3300  1999.0     chrysler                300m
# 376         birmingham   3999  2003.0     infiniti           g35 sedan
# 383         birmingham   2550  2004.0     cadillac                 srx
# ...                ...    ...     ...          ...                 ...
# 22106  fresno / madera  15995  2015.0          kia           optima ex
# 22107  fresno / madera   3600  1994.0       nissan              sentra
# 22108  fresno / madera  17995  2018.0    chevrolet           impala ls
# 22111  fresno / madera  10700  2011.0        honda      civic ex coupe
# 22112  fresno / madera  12200  2011.0        buick  lacrosse cxl sedan
#
#        condition    cylinders fuel  odometer title_status transmission drive  \
# 352         good  6 cylinders  gas  160218.0        clean    automatic   fwd
# 355         good  4 cylinders  gas  162005.0        clean    automatic   rwd
# 358         good  6 cylinders  gas  162026.0        clean    automatic   fwd
# 376         good  6 cylinders  gas  233830.0        clean    automatic   rwd
# 383         good  6 cylinders  gas  224105.0        clean    automatic   rwd
# ...          ...          ...  ...       ...          ...          ...   ...
# 22106       good  4 cylinders  gas   75290.0        clean    automatic   fwd
# 22107       good  6 cylinders  gas  103000.0        clean       manual   4wd
# 22108       good  4 cylinders  gas   67000.0        clean    automatic   fwd
# 22111  excellent  4 cylinders  gas  171457.0        clean    automatic   fwd
# 22112  excellent  6 cylinders  gas  107885.0        clean    automatic   fwd
#
#         type paint_color state        lat        long
# 352    sedan        blue    al  33.455361  -86.962474
# 355    sedan       white    al  33.455361  -86.962474
# 358    sedan       white    al  33.455361  -86.962474
# 376    sedan       white    al  33.455361  -86.962474
# 383      SUV       white    al  33.455361  -86.962474
# ...      ...         ...   ...        ...         ...
# 22106  sedan        grey    ca  36.744394 -119.789278
# 22107  sedan       white    ca  36.791800 -119.880100
# 22108  sedan       black    ca  36.744394 -119.789278
# 22111  coupe      silver    ca  36.770363 -119.699929
# 22112  sedan       white    ca  36.770345 -119.699972
#
# [3329 rows x 17 columns]

# %% [markdown]
# #### There are 3329 duplicate rows in the dataset. We should drop the duplicate values.

# %%
# Drop all duplicate values.

df.drop_duplicates(inplace = True)

# Reset index after dropping.

df.reset_index(drop = True, inplace = True)

# %%
# Check first 5 rows

df.head()
# Out:
#    region  price    year manufacturer                     model  condition  \
# 0  auburn  33590  2014.0          gmc  sierra 1500 crew cab slt       good
# 1  auburn  22590  2010.0    chevrolet            silverado 1500       good
# 2  auburn  39590  2020.0    chevrolet       silverado 1500 crew       good
# 3  auburn  30990  2017.0       toyota      tundra double cab sr       good
# 4  auburn  15000  2013.0         ford                 f-150 xlt  excellent
#
#      cylinders fuel  odometer title_status transmission drive    type  \
# 0  8 cylinders  gas   57923.0        clean        other   4wd  pickup
# 1  8 cylinders  gas   71229.0        clean        other   4wd  pickup
# 2  8 cylinders  gas   19160.0        clean        other   4wd  pickup
# 3  8 cylinders  gas   41124.0        clean        other   4wd  pickup
# 4  6 cylinders  gas  128000.0        clean    automatic   rwd   truck
#
#   paint_color state     lat     long
# 0       white    al  32.590 -85.4800
# 1        blue    al  32.590 -85.4800
# 2         red    al  32.590 -85.4800
# 3         red    al  32.590 -85.4800
# 4       black    al  32.592 -85.5189

# %%
# Get present 'year'

today = date.today()

# Create a new feature 'car_age' from 'year' feature.

df['car_age'] = today.year - df['year'].astype(int)

# %%
# Drop 'year' feature

df.drop('year', axis = 1, inplace = True)

# %%
# Check dataset after dropping 'year' feature

df
# Out:
#                 region  price manufacturer                     model  \
# 0               auburn  33590          gmc  sierra 1500 crew cab slt
# 1               auburn  22590    chevrolet            silverado 1500
# 2               auburn  39590    chevrolet       silverado 1500 crew
# 3               auburn  30990       toyota      tundra double cab sr
# 4               auburn  15000         ford                 f-150 xlt
# ...                ...    ...          ...                       ...
# 18784  fresno / madera   6200      hyundai      sonata gls 4dr sedan
# 18785  fresno / madera  13500         ford         workhorse stepvan
# 18786  fresno / madera   3000        honda                    accord
# 18787  fresno / madera  14777      hyundai                   elantra
# 18788  fresno / madera  12995      hyundai        elantra sesedan 6a
#
#        condition    cylinders    fuel  odometer title_status transmission  \
# 0           good  8 cylinders     gas   57923.0        clean        other
# 1           good  8 cylinders     gas   71229.0        clean        other
# 2           good  8 cylinders     gas   19160.0        clean        other
# 3           good  8 cylinders     gas   41124.0        clean        other
# 4      excellent  6 cylinders     gas  128000.0        clean    automatic
# ...          ...          ...     ...       ...          ...          ...
# 18784  excellent  4 cylinders     gas  169540.0        clean    automatic
# 18785   like new  6 cylinders  diesel  221000.0        clean    automatic
# 18786       good  6 cylinders     gas  226000.0        clean    automatic
# 18787       good  4 cylinders     gas   99275.0        clean    automatic
# 18788  excellent  4 cylinders     gas  106196.0        clean    automatic
#
#       drive    type paint_color state        lat        long  car_age
# 0       4wd  pickup       white    al  32.590000  -85.480000        7
# 1       4wd  pickup        blue    al  32.590000  -85.480000       11
# 2       4wd  pickup         red    al  32.590000  -85.480000        1
# 3       4wd  pickup         red    al  32.590000  -85.480000        4
# 4       rwd   truck       black    al  32.592000  -85.518900        8
# ...     ...     ...         ...   ...        ...         ...      ...
# 18784   fwd   sedan        grey    ca  36.770363 -119.699886       12
# 18785   4wd   sedan       white    ca  37.105900 -120.280200       18
# 18786   4wd   sedan       black    ca  36.791800 -119.880100       21
# 18787   fwd   sedan      silver    ca  36.790784 -119.789897        2
# 18788   4wd   sedan       white    ca  37.637869 -120.975297        4
#
# [18789 rows x 17 columns]

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# ### 1. Univariate Analysis

# %% [markdown]
# #### We will see Distribution of Numerical Features.

# %%
# Plotting histogram 

plt.figure(figsize = (10, 5))
plt.hist(df['car_age'], bins = 30, edgecolor = 'black')
plt.title("Distribution of Car's Age.", fontsize = 18)
plt.xlabel('Car Age', fontsize = 14)
plt.ylabel('Count', fontsize = 14)
plt.show()

# %% [markdown]
# #### We can see that the 'Distribution of Car Age' is positively skewed. Most of the cars  fall in the range 1- 8 year's old.

# %%
# Plotting histogram 

plt.figure(figsize = (10, 5))
plt.hist(df['odometer'], bins = 30, edgecolor = 'black', color = 'orange')
plt.title("Distribution of Odometer.", fontsize = 18)
plt.xlabel('Odometer', fontsize = 14)
plt.ylabel('Count', fontsize = 14)
plt.show()

# %% [markdown]
# #### We can see that the 'Distribution of Odometer' is positively skewed. Most of the cars has travelled distance between range

# %%
# Plotting histogram 

plt.figure(figsize = (10, 5))
plt.hist(df['price'], bins = 30, edgecolor = 'black', color = '#999966')
plt.title("Distribution of Price.", fontsize = 18)
plt.xlabel("Price in Dollar ($)", fontsize = 14)
plt.ylabel('Count', fontsize = 14)
plt.show()

# %% [markdown]
# #### We will see Count of Cateorical Features.

# %%
# Get count of fuel in %
fuel = (df['fuel'].value_counts()/len(df['fuel'])*100).round(2)

# Plotting bar graph
plt.figure(figsize = (10, 5))
sns.barplot(x = fuel.keys(), y = fuel.values, palette = 'rocket')
plt.title('Count of Fuel Type', fontsize = 18)
plt.xlabel('Fuel Type', fontsize = 13)
plt.ylabel('Count in %', fontsize = 13)
plt.xticks(fontsize = 12)
plt.yticks(np.arange(0,100,10), fontsize = 12)

# plotting values on top of bar
for i in range(len(fuel.keys())):
    plt.text(i, fuel[i]+3, fuel[i], ha = 'center', size = 12)

plt.show()

print(fuel)
# Out:
# gas         80.10
# other       10.41
# diesel       7.44
# hybrid       1.48
# electric     0.57
# Name: fuel, dtype: float64

# %% [markdown]
# #### The most of the Cars has 'gas' as there fuel type. Around 80% of Cars are of 'gas' and remaining 20% Cars are of different fuel type.

# %%
# Get count of transmission in %
transmission = (df['transmission'].value_counts()/len(df['transmission'])*100).round(1)

# Plotting pie chart 
plt.figure(figsize = (8,8))
plt.pie(transmission, labels = ['Automatic', 'Other', 'Manual'], autopct = '%1.1f%%', textprops = dict(color = 'black', size = 16), explode = [0.001, 0.001, 0.001], colors = ['#ff704d', '#00ace6', '#e6e600'], shadow = True)
plt.legend(title = 'Transmission', loc = 'best')
plt.title('Count of Transmission.', fontsize = 20)
plt.show()

print(transmission)
# Out:
# automatic    73.0
# other        21.9
# manual        5.1
# Name: transmission, dtype: float64

# %% [markdown]
# #### Around 73% Cars has 'Automatic' transmission  while 22% Cars has 'Other' as transmission & only 5% Cars has 'Manual' transmisson.

# %%
# Get count of drive in %
drive = (df['drive'].value_counts()/len(df['drive'])*100).round(1)

# Plotting pie chart
plt.figure(figsize = (8,8))
plt.pie(drive, labels = ['4 wheel drive', 'Front wheel drive', 'Rear wheel drive'], autopct = '%1.1f%%', textprops = dict(color = 'black', size = 16), shadow = True)
plt.legend(title = 'Drive')
plt.title('Count of Drive.', fontsize = 20)
plt.show()

print(drive)
# Out:
# 4wd    56.7
# fwd    27.0
# rwd    16.3
# Name: drive, dtype: float64

# %% [markdown]
# #### Around 56% Cars has '4wheeldrive' while 27% Cars has 'Frontwheeldrive'  & only 16% Cars has 'Rearwheeldrive'.

# %% [markdown]
# ### 2. Bivariate Analysis

# %% [markdown]
# ### Bivariate Analysis of Numerical Features.

# %%
# Plotting scatter plot to see relationship between 'car_age' & 'price' feature.

plt.figure(figsize = (10, 5))
plt.scatter(df['car_age'], df['price'], color = 'orange')
plt.xlabel('Car Age', fontsize = 14)
plt.ylabel('Price n Dollar ($)', fontsize = 14)
plt.show()

# %% [markdown]
# #### From graph we can see there's negative correlation between 'Car Age' & 'Price'. As age of car increases the price decreases.
#
# #### Cars less than 10 years old has the highest price.

# %%
# Plotting scatter plot to see relationship between 'odometer' & 'price' feature.

plt.figure(figsize = (10, 5))
sns.scatterplot(x = df['odometer'], y = df['price'], s = 50)
plt.xlabel('Odometer in Miles', fontsize = 14)
plt.ylabel('Price in Dollar ($)', fontsize = 14)
plt.show()

# %% [markdown]
# #### Here also we can see there's negative correlation between 'Odometer' & 'Price'.
#
# #### Cars driven less than 50000  miles has the highest price.

# %% [markdown]
# ### Bivariate Analysis of Categorical Features.

# %%
# Get mean price of transmission
trans_price = df.groupby('transmission')['price'].mean().round(2)

# Plotting bar graph
plt.figure(figsize = (10, 5))
sns.barplot(x = trans_price.keys(), y = trans_price.values, palette = 'mako_r')
#plt.title('Count of Fuel Type', fontsize = 20)
plt.xlabel('Transmission', fontsize = 14)
plt.ylabel('Price in Dollar', fontsize = 14)
plt.xticks(ticks = [0, 1, 2], labels = ['Automatic', 'Manual', 'Other'], fontsize = 12)
plt.yticks(np.arange(0,40000,5000), fontsize = 10)

# Plotting values on top of bar
for i in range(len(trans_price.keys())):
    plt.text(i, trans_price[i]+2000, trans_price[i], ha = 'center', size = 12)

plt.show()

print(trans_price)
# Out:
# transmission
# automatic    20173.31
# manual       15499.85
# other        28320.37
# Name: price, dtype: float64

# %% [markdown]
# #### The average price of  cars whose transmission is 'Other' is 28320.37. The average price for 'Automatic'  cars is 20173.31 dollar & for 'Manual' its 15499.85
#
# #### Among all 'Other' has the highest price.

# %%
# Get mean price of fuel
fuel_price = df.groupby('fuel')['price'].mean().round(2)

# Plotting bar graph
plt.figure(figsize = (10, 5))
sns.barplot(x = fuel_price.keys(), y = fuel_price.values, palette = 'gist_earth')
#plt.title('Count of Fuel Type', fontsize = 20)
plt.xlabel('Fuel', fontsize = 14)
plt.ylabel('Price in Dollar', fontsize = 14)
plt.xticks(ticks = [0, 1, 2, 3, 4], labels = ['Diesel', 'Electric', 'Gas', 'Hybrid', 'Other'], fontsize = 12)
plt.yticks(np.arange(0,45000,5000), fontsize = 10)

# Plotting values on top of bar
for i in range(len(fuel_price.keys())):
    plt.text(i, fuel_price[i]+1000, fuel_price[i], ha = 'center', size = 12)

plt.show()

print(fuel_price)
# Out:
# fuel
# diesel      36398.52
# electric    25180.41
# gas         19357.94
# hybrid      17275.63
# other       29889.74
# Name: price, dtype: float64

# %% [markdown]
# #### The price of 'Diesel' cars are high. The average price of 'Diesel' car  is 36398.52.
#
# #### The price of 'Hybrid' cars are low. The average price of 'Hybrid' car  is 36398.52.

# %%
# Get mean price of cylinders
cylinders_price = (df.groupby('cylinders')['price'].mean().round(2)).nsmallest(15)

# Plotting bar graph
plt.figure(figsize = (10, 5))
sns.barplot(x = cylinders_price.keys(), y = cylinders_price.values, palette = 'magma_r')
#plt.title('Count of Fuel Type', fontsize = 20)
plt.xlabel('Cylinders', fontsize = 14)
plt.ylabel('Price in Dollar', fontsize = 14)
plt.xticks(fontsize = 12)
plt.yticks(np.arange(0,45000,5000), fontsize = 10)

# Plotting values on top of bar
for i in range(len(cylinders_price.keys())):
    plt.text(i, cylinders_price[i]+2000, cylinders_price[i], ha = 'center', size = 12)

plt.show()

print(cylinders_price)
# Out:
# cylinders
# 5 cylinders      9764.23
# 4 cylinders     13177.11
# 3 cylinders     13223.00
# other           20721.53
# 6 cylinders     22682.08
# 10 cylinders    24008.74
# 8 cylinders     27045.99
# 12 cylinders    35420.00
# Name: price, dtype: float64

# %% [markdown]
# #### The car with '12 cylinder' engine has the highest price & the average price of '12 cylinder' engine car is 35420.
#
# #### As the number of cylinders in engine increases the price also increases.

# %%
# Get mean price of manufacturer
man_price = (df.groupby('manufacturer')['price'].mean().round(2)).nlargest(10)

# Plotting bar graph
plt.figure(figsize = (10, 5))
sns.barplot(x = man_price.keys(), y = man_price.values, palette = 'inferno_r')
#plt.title('Count of Fuel Type', fontsize = 20)
plt.xlabel('Manufacturer', fontsize = 14)
plt.ylabel('Price in Dollar', fontsize = 14)
plt.xticks(ticks = np.arange(0, 10), labels = [i.capitalize() for i in man_price.keys()], fontsize = 12)
plt.yticks(np.arange(0,120000,20000), fontsize = 10)

# Plotting values on top of bar
for i in range(len(man_price.keys())):
    plt.text(i, man_price[i]+2000, man_price[i], ha = 'center', size = 12)

plt.show()

print(man_price)
# Out:
# manufacturer
# ferrari       89966.67
# tesla         38835.09
# ram           33249.98
# porsche       32842.43
# jaguar        29843.22
# alfa-romeo    29759.79
# rover         28953.79
# audi          28138.20
# gmc           27541.44
# acura         24792.75
# Name: price, dtype: float64

# %% [markdown]
# #### The top 10 manufacturer whose car prices are high. The average price for 'Ferrari' cars is 89966.67 which is the highest among all.

# %%
# Get mean price of manufacturer
man_price = (df.groupby('manufacturer')['price'].mean().round(2)).nsmallest(10)

# Plotting bar graph
plt.figure(figsize = (10, 5))
sns.barplot(x = man_price.keys(), y = man_price.values, palette = 'copper')
#plt.title('Count of Fuel Type', fontsize = 20)
plt.xlabel('Manufacturer', fontsize = 14)
plt.ylabel('Price in Dollar', fontsize = 14)
plt.xticks(ticks = np.arange(0, 10), labels = [i.capitalize() for i in man_price.keys()], fontsize = 12)
plt.yticks(np.arange(0,20000,2000), fontsize = 10)

# Plotting values on top of bar
for i in range(len(man_price.keys())):
    plt.text(i, man_price[i]+500, man_price[i], ha = 'center', size = 12)
    
plt.show()

print(man_price)
# Out:
# manufacturer
# mercury        3457.42
# saturn         4888.38
# pontiac        6808.45
# fiat          13505.38
# chrysler      13627.35
# honda         13752.34
# hyundai       13779.04
# kia           14590.88
# volkswagen    15174.61
# buick         15371.65
# Name: price, dtype: float64

# %% [markdown]
# #### The top 10 manufacturer whose car prices are low. The average price for 'mercury' cars is 89966.673457.42 which is the highest among all.

# %%
# Get count of 'model'
car_count = df['model'].value_counts().nlargest(10)

# Create a list
pop_car = []

# Looping through 'car_count'
for i in car_count.keys():
    name = df.loc[df['model'] == i]['manufacturer'].mode() + ': ' + i         # Concat manufacturer & model name
    pop_car.append(name[0])                                                   # Append name to list

#  Plotting bar graph
plt.figure(figsize = (10, 5))
sns.barplot(x = pop_car, y = car_count.values, palette = 'icefire_r')
plt.title('Top 10 Popular Cars', fontsize = 18)
plt.xlabel('Manufacturer & Car Model', fontsize = 14)
plt.ylabel('Count', fontsize = 14)
plt.xticks(rotation = 45, ticks = np.arange(0, 10), labels = [i.capitalize() for i in pop_car], fontsize = 12)
plt.yticks(np.arange(0,700,100), fontsize = 10)

# Plotting values on top of bar
for i in range(len(pop_car)):
    plt.text(i, car_count[i]+10, car_count[i], ha = 'center', size = 12)
    
plt.show()

print(car_count)
# Out:
# f-150             523
# silverado 1500    253
# 1500              177
# 2500              145
# silverado         139
# tacoma            123
# camry             122
# wrangler          120
# altima            111
# civic             101
# Name: model, dtype: int64

# %% [markdown]
# #### The top 10 popular cars. Ford f-150 is the most popular car

# %%
# Get count of 'model'
car_count = df['model'].value_counts().nlargest(10)

# Create a list
pop_car = []
pop_price = []

# Looping through 'car_count'
for i in car_count.keys():
    name = df.loc[df['model'] == i]['manufacturer'].mode() + ': ' + i          # Concat manufacturer & model name
    price = df.loc[df['model'] == i]['price'].mean()                           # Get mean price 
    
    pop_car.append(name[0])                                                    # Append name to list
    pop_price.append(round(price ,2))                                          # Append price to list

#  Plotting bar graph
plt.figure(figsize = (10, 5))
sns.barplot(x = pop_car, y = pop_price, palette = 'gist_heat_r')
plt.title('Price of Top 10 Popular Cars', fontsize = 18)
plt.xlabel('Manufacturer & Car Model', fontsize = 14)
plt.ylabel('Price in Dollars', fontsize = 14)
plt.xticks(rotation = 45, ticks = np.arange(0, 10), labels = [i.capitalize() for i in pop_car], fontsize = 12)
plt.yticks(np.arange(0,50000,5000), fontsize = 10)

# Plotting values on top of bar
for i in range(len(pop_car)):
    plt.text(i, pop_price[i]+1000, pop_price[i], ha = 'center', size = 12)
    
plt.show()

# %% [markdown]
# #### The average price of top 10 popular cars. 'Ram: 2500' has the highest price which is 39238.

# %%
# Get count of 'type'
type_count = df['type'].value_counts().sort_index()

# Plotting bar graph
plt.figure(figsize = (10, 5))
sns.barplot(x = type_count.keys(), y = type_count.values, palette = 'turbo')
plt.xlabel('Car Type', fontsize = 14)
plt.ylabel('Count', fontsize = 14)
plt.xticks(ticks = np.arange(0, 13), rotation = 45, labels = [i.capitalize() for i in type_count.keys()], fontsize = 12)
plt.yticks(np.arange(0,9000,1000), fontsize = 10)

# Plotting values on top of bar
for i in range(len(type_count)):
    plt.text(i, type_count[i]+200, type_count[i], ha = 'center', size = 12)
    
plt.show()

print(type_count)
# Out:
# SUV            3280
# bus              15
# convertible     322
# coupe           810
# hatchback       880
# mini-van        192
# offroad          49
# other          1109
# pickup         2640
# sedan          7386
# truck          1314
# van             357
# wagon           435
# Name: type, dtype: int64

# %% [markdown]
# #### The 'Sedan', 'SUV' & 'Pickup' cars hase the highest count.

# %%
# Get price of 'type'
type_price = df.groupby('type')['price'].mean().sort_index()

# Plotting bar graph
plt.figure(figsize = (10, 5))
sns.boxplot(x = df['type'], y = df['price'])
plt.xlabel('Car Type', fontsize = 14)
plt.ylabel('Price in Dollars', fontsize = 14)
plt.xticks(ticks = np.arange(0, 13), rotation = 45, labels = [i.capitalize() for i in type_price.keys()], fontsize = 12)
plt.yticks(fontsize = 10)

plt.show()

print(type_price)
# Out:
# type
# SUV            20502.621341
# bus            14002.000000
# convertible    20320.714286
# coupe          23105.372840
# hatchback      17435.226136
# mini-van       12202.364583
# offroad        17837.673469
# other          30142.083859
# pickup         31680.435227
# sedan          17699.269835
# truck          26655.704718
# van            20228.512605
# wagon          15778.464368
# Name: price, dtype: float64

# %% [markdown]
# ####  The average price of 'pickup' & 'other' car type has the highest price. The average price of 'pickup' car type is 31680.43 .

# %% [markdown]
# ### 3. Multivariate Analysis

# %%
# Get mean price of transmission w.r.t fuel

trans_fuel_price = df.groupby(['transmission', 'fuel'])['price'].mean().round(2)
trans_fuel_price.to_frame().T
# Out:
# transmission automatic                                           manual  \
# fuel            diesel  electric       gas   hybrid     other    diesel
# price         37831.21  26483.34  17600.52  15664.7  31344.31  22098.07
#
# transmission                                  other                      \
# fuel               gas   hybrid     other    diesel  electric       gas
# price         14588.43  19990.0  18963.38  28835.26  24057.19  28135.18
#
# transmission
# fuel            hybrid     other
# price         22469.35  29227.48

# %%
# Plotting bar graph

plt.figure(figsize = (10, 5))
sns.barplot(x = df['transmission'], y = df['price'], hue = df['fuel'], ci = None, palette = 'CMRmap')
#plt.title('Count of Fuel Type', fontsize = 20)
plt.xlabel('Transmission', fontsize = 14)
plt.ylabel('Price in Dollar', fontsize = 14)
plt.xticks(ticks = np.arange(0, 3), labels = [i.capitalize() for i in df['transmission'].unique()], fontsize = 12)
plt.yticks(fontsize = 10)
plt.legend(title = 'Fuel', labels = [i.capitalize() for i in df['fuel'].unique()], loc = 'upper right', title_fontsize = 11, fontsize = 10, shadow = True)
plt.show()

# %% [markdown]
# #### The cars with 'Automatic' & 'Manual' transmission with 'Diesel' fuel has the highest price.

# %%
# Creating a function to get New Dataset of region

def region_wise_data(data):
    new_region = []
    new_lat = []
    new_long = []
    count = []

    # Looping through region feature to get latitude, longitude & count vlaues 
    for i in data['region'].unique():
        lat_ = data[data['region'] == i]['lat'].value_counts().head(1).keys()[0]
        long_ = data[data['region'] == i]['long'].value_counts().head(1).keys()[0]
        value_ = len(data[data['region'] == i])
        new_region.append(i)
        new_lat.append(lat_)
        new_long.append(long_)
        count.append(value_)
    
    # Create a new dataset & return the dataset
    region_data = pd.DataFrame({'region': new_region, 'lat': new_lat, 'long': new_long, 'count': count})

    return region_data

# %%
# Statewise dataset with region

# Alabama State Dataset
al_state_data = region_wise_data(df[df['state'] == 'al'])

# Alaska State Dataset
ak_state_data = region_wise_data(df[df['state'] == 'ak'])

# Arizona State Dataset
az_state_data = region_wise_data(df[df['state'] == 'az'])

# Arkansas State Dataset
ar_state_data = region_wise_data(df[df['state'] == 'ar'])

# California State Dataset
ca_state_data = region_wise_data(df[df['state'] == 'ca'])

# %%
# Check State Dataset

al_state_data
# Out:
#                      region        lat       long  count
# 0                    auburn  32.590000 -85.480000    133
# 1                birmingham  33.520000 -86.790000   1112
# 2                    dothan  31.230000 -85.400000    290
# 3  florence / muscle shoals  33.779214 -84.411811    151
# 4          gadsden-anniston  34.010000 -86.010000    164
# 5      huntsville / decatur  34.570000 -86.980000   1056
# 6                    mobile  30.668786 -88.105874    478
# 7                montgomery  32.350000 -86.280000    324
# 8                tuscaloosa  33.230000 -87.540000    150

# %%
# Creating a base map
region_map = folium.Map(location = [39.33699860995735, -98.42457180194508], zoom_start = 3, tiles = 'StamenTerrain')

# Plotting count of cars in Alabama state on map 
for lat, long, name, count in zip(al_state_data['lat'], al_state_data['long'], al_state_data['region'], al_state_data['count']):
    folium.CircleMarker([lat, long], radius = count/30, popup = ('<strong> State: </strong>'+ 'Alabama' + '<br>''<strong> Region: </strong>' + str(name).capitalize() + '<br>''<strong> Count: </strong>' + str(count) + '<br>'), color = 'red', fill_color = 'red', fill_opacity = 0.2).add_to(region_map)

# Plotting count of cars in Alaska state on map 
for lat, long, name, count in zip(ak_state_data['lat'], ak_state_data['long'], ak_state_data['region'], ak_state_data['count']):
    folium.CircleMarker([lat, long], radius = count/30, popup = ('<strong> State: </strong>'+ 'Alaska' + '<br>''<strong> Region: </strong>' + str(name).capitalize() + '<br>''<strong> Count: </strong>' + str(count) + '<br>'), color = 'blue', fill_color = 'blue', fill_opacity = 0.2).add_to(region_map)

# Plotting count of cars in Arizona state on map 
for lat, long, name, count in zip(az_state_data['lat'], az_state_data['long'], az_state_data['region'], az_state_data['count']):
    folium.CircleMarker([lat, long], radius = count/30, popup = ('<strong> State: </strong>'+ 'Arizona' + '<br>''<strong> Region: </strong>' + str(name).capitalize() + '<br>''<strong> Count: </strong>' + str(count) + '<br>'), color = 'green', fill_color = 'green', fill_opacity = 0.2).add_to(region_map)

# Plotting count of cars in Arkansas state on map 
for lat, long, name, count in zip(ar_state_data['lat'], ar_state_data['long'], ar_state_data['region'], ar_state_data['count']):
    folium.CircleMarker([lat, long], radius = count/30, popup = ('<strong> State: </strong>'+ 'Arkansas' + '<br>''<strong> Region: </strong>' + str(name).capitalize() + '<br>''<strong> Count: </strong>' + str(count) + '<br>'), color = 'orange', fill_color = 'orange', fill_opacity = 0.2).add_to(region_map)

# Plotting count of cars in California state on map 
for lat, long, name, count in zip(ca_state_data['lat'], ca_state_data['long'], ca_state_data['region'], ca_state_data['count']):
    folium.CircleMarker([lat, long], radius = count/30, popup = ('<strong> State: </strong>'+ 'California' + '<br>''<strong> Region: </strong>' + str(name).capitalize() + '<br>''<strong> Count: </strong>' + str(count) + '<br>'), color = 'cyan', fill_color = 'cyan', fill_opacity = 0.2).add_to(region_map)

# %%
# Calling map object

region_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_48ab336d2db84f35abd74971e907c7b3%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_48ab336d2db84f35abd74971e907c7b3%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_48ab336d2db84f35abd74971e907c7b3%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_48ab336d2db84f35abd74971e907c7b3%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B39.33699860995735%2C%20-98.42457180194508%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# ## Data Preprocessing

# %%
df.head()
# Out:
#    region  price manufacturer                     model  condition  \
# 0  auburn  33590          gmc  sierra 1500 crew cab slt       good
# 1  auburn  22590    chevrolet            silverado 1500       good
# 2  auburn  39590    chevrolet       silverado 1500 crew       good
# 3  auburn  30990       toyota      tundra double cab sr       good
# 4  auburn  15000         ford                 f-150 xlt  excellent
#
#      cylinders fuel  odometer title_status transmission drive    type  \
# 0  8 cylinders  gas   57923.0        clean        other   4wd  pickup
# 1  8 cylinders  gas   71229.0        clean        other   4wd  pickup
# 2  8 cylinders  gas   19160.0        clean        other   4wd  pickup
# 3  8 cylinders  gas   41124.0        clean        other   4wd  pickup
# 4  6 cylinders  gas  128000.0        clean    automatic   rwd   truck
#
#   paint_color state     lat     long  car_age
# 0       white    al  32.590 -85.4800        7
# 1        blue    al  32.590 -85.4800       11
# 2         red    al  32.590 -85.4800        1
# 3         red    al  32.590 -85.4800        4
# 4       black    al  32.592 -85.5189        8

# %%
# Drop unwanted columns

df.drop(['region', 'paint_color','model', 'lat', 'long'], axis = 1, inplace = True)

# %%
# Check dataset after dropping

df.head()
# Out:
#    price manufacturer  condition    cylinders fuel  odometer title_status  \
# 0  33590          gmc       good  8 cylinders  gas   57923.0        clean
# 1  22590    chevrolet       good  8 cylinders  gas   71229.0        clean
# 2  39590    chevrolet       good  8 cylinders  gas   19160.0        clean
# 3  30990       toyota       good  8 cylinders  gas   41124.0        clean
# 4  15000         ford  excellent  6 cylinders  gas  128000.0        clean
#
#   transmission drive    type state  car_age
# 0        other   4wd  pickup    al        7
# 1        other   4wd  pickup    al       11
# 2        other   4wd  pickup    al        1
# 3        other   4wd  pickup    al        4
# 4    automatic   rwd   truck    al        8

# %% [markdown]
# ### Converting categorical features to numerical features.
#
# ### Here LabelEncoder is used:

# %%
# We will append these LabelEncoder values to list for prediction 

# Getting all categorical features
cat_fea = [i for i in df.columns if df[i].dtypes == 'O']

# Create a empty list
le = []

# Looping through 'cat_fea' variable
for i in range(len(cat_fea)):
    encoder_i = LabelEncoder()                                    # Create Label Encoder object 
    le.append(encoder_i)                                          # Append Label Encoder object to list
    df[cat_fea[i]] = encoder_i.fit_transform(df[cat_fea[i]])      # Convert categorical features to numeric

# %%
# Ckeck dataset

df.head()
# Out:
#    price  manufacturer  condition  cylinders  fuel  odometer  title_status  \
# 0  33590            12          2          6     2   57923.0             0
# 1  22590             6          2          6     2   71229.0             0
# 2  39590             6          2          6     2   19160.0             0
# 3  30990            35          2          6     2   41124.0             0
# 4  15000            11          0          5     2  128000.0             0
#
#    transmission  drive  type  state  car_age
# 0             2      0     8      1        7
# 1             2      0     8      1       11
# 2             2      0     8      1        1
# 3             2      0     8      1        4
# 4             0      2    10      1        8

# %% [markdown]
# ### Correlation Matrix

# %%
# Plotting HeatMap

plt.figure(figsize = (14, 8))
sns.heatmap(df.corr(), annot = True)
plt.show()

# %% [markdown]
# ## Model Building

# %%
# Filtering Independent & Dependent features.

X = df.drop('price', axis = 1)
y = df['price']

# %%
# Splitting the dataset for training & testing

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 19)

# %%
# Creating a function to try different ML models.

def base_model(xtrain, xtest, ytrain, ytest, model_names):
    train_score = []
    test_score = []
    mse_score = []
    mae_score = []
    mape_score = []
    train_adj_r2 = []
    test_adj_r2 = []
    
    # Looping through a list of models. 
    for name in model_names:                     
        
        model = name()                     # Create a model object
        model.fit(xtrain, ytrain)          # Training the model

        pred = model.predict(xtest)        # Predicting on test data

        train_score.append(model.score(xtrain, ytrain).round(5))               # Append train score to list
        test_score.append(model.score(xtest, ytest).round(5))                  # Append test score to list
        mae_score.append(mean_absolute_error(ytest, pred).round(5)) 
            
    # Creating a dataframe of different models with train & test scores
    dataframe = pd.DataFrame({'Base Models': ['Linear Regression', 'Ridge', 'Lasso', 'KNN', 'Decision Tree', 'Random Forest', 'XGBoost', 'AdaBoost'], 'Train Score': train_score, 'Test Score': test_score, 'MAE': mae_score})
    
    return dataframe

# %%
# Create list of models 

names = [LinearRegression, Ridge, Lasso, KNeighborsRegressor, DecisionTreeRegressor, RandomForestRegressor, XGBRegressor, AdaBoostRegressor]

# Calling base_model function
result = base_model(X_train, X_test, y_train, y_test, names)

result
# Out:
#          Base Models  Train Score  Test Score          MAE
# 0  Linear Regression      0.53259     0.54153   7178.98059
# 1              Ridge      0.53259     0.54153   7178.99524
# 2              Lasso      0.53259     0.54152   7178.97180
# 3                KNN      0.56054     0.34644   8287.49026
# 4      Decision Tree      0.99848     0.72273   4305.61606
# 5      Random Forest      0.97388     0.83833   3490.02593
# 6            XGBoost      0.90815     0.84135   3752.61335
# 7           AdaBoost      0.26625     0.25882  10356.28673

# %% [markdown]
# #### The RandomForest & XGBoost model is performing best out of all.
#
# #### RandomForest was giving better results as compared to XGBoost, so I decided to go with RandomForest.

# %% [markdown]
# ### Hyperparameter Tuning

# %%
# Create a random forest object

rf = RandomForestRegressor()

# %%
# Create a dictionary of parameters

params = {'n_estimators': [i for i in range(100, 1100, 100)],
         'max_depth': [i for i in range(5, 105, 10)],
         'max_features': ['auto', 'sqrt']}

# %%
#rand = RandomizedSearchCV(rf, params, scoring = 'neg_mean_squared_error', n_jobs = -1)

# %%
# Create a random forest object with hyperparameters

rf_hy = RandomForestRegressor(n_estimators = 800, max_features = 'sqrt', max_depth = 45) 

# Train the model

rf_hy.fit(X_train, y_train)

# Predict on test data
pred = rf_hy.predict(X_test)

# Print first 5 predictions  
print('First 5 prediction:', pred[:5])
# Out:
# First 5 prediction: [ 5781.17970238 32304.91125     4030.20458333 26126.47125
#  34889.53125   ]

# %%
# Print first 5 actual values  

print('Actual 5 values:\n')
print(y_test[:5])
# Out:
# Actual 5 values:
#
# 11165     4990
# 9597     31990
# 9360      2300
# 8400     24991
# 16909    34590
# Name: price, dtype: int64

# %% [markdown]
# ## Model Evaluation

# %%
# Model Score & Error

print('Train Score:', (rf_hy.score(X_train, y_train)*100).round(2), '%')
print('Test Score:', (rf_hy.score(X_test, y_test)*100).round(2),'%','\n')
print('MAE:', (mean_absolute_error(y_test, pred)).round(2))
print('RMSE:', (np.sqrt(mean_squared_error(y_test, pred))).round(2))
# Out:
# Train Score: 97.67 %
# Test Score: 84.79 %
#
# MAE: 3436.94
# RMSE: 5600.73

# %%
# Model evaluation 

sns.kdeplot(x = y_test)
sns.kdeplot(x = pred, color = 'orange')
plt.legend(title = 'Actual vs Predicted', labels = ['Actual', 'Predicted'], loc = 'upper right')

plt.show()

# %% [markdown]
# ### Cross Validation

# %%
# Cross Validation 

score = cross_val_score(rf_hy, X, y, cv = 10)

# %%
# Cross Validation Score

print('The average accuracy of the model is'  + "\033[1m" + ' {} %'.format((score.mean().round(2))*100) + "\033[0m")
# Out:
# The average accuracy of the model is 82.0 %

# %% [markdown]
# ### Save the model

# %%
import pickle

# %%
# saving model

# file = open('rfRegressor_model.pkl', 'wb')

# pickle.dump(rf_hy, file)
# file.close()                   # Always close the file after saving the model or it will throw an error

# %%
# Here labelencoder model is also saved for predictions 

# file = open('model_encoder.pkl', 'wb')

# pickle.dump(le, file)
# file.close()                   # Always close the file after saving the model or it will throw an error
